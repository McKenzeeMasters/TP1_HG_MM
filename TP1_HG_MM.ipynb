# %% [markdown]
# # Team Project One: Hannah Garrett and McKenzee Masters
# ## Using Superstore file

# %%
pip install prettytable
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from prettytable import PrettyTable as pt

# %%
Super=pd.read_csv('Superstore.csv', encoding='windows-1252')
Super.head()
# Out:
#    Row ID        Order ID  Order Date   Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2016-152156   11/8/2016  11/11/2016    Second Class    CG-12520
# 1       2  CA-2016-152156   11/8/2016  11/11/2016    Second Class    CG-12520
# 2       3  CA-2016-138688   6/12/2016   6/16/2016    Second Class    DV-13045
# 3       4  US-2015-108966  10/11/2015  10/18/2015  Standard Class    SO-20335
# 4       5  US-2015-108966  10/11/2015  10/18/2015  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City  ...  \
# 0      Claire Gute   Consumer  United States        Henderson  ...
# 1      Claire Gute   Consumer  United States        Henderson  ...
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  ...
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
#
#   Postal Code  Region       Product ID         Category Sub-Category  \
# ...

# %%
Super.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Row ID         9994 non-null   int64
#  1   Order ID       9994 non-null   object
#  2   Order Date     9994 non-null   object
#  3   Ship Date      9994 non-null   object
#  4   Ship Mode      9994 non-null   object
#  5   Customer ID    9994 non-null   object
#  6   Customer Name  9994 non-null   object
#  7   Segment        9994 non-null   object
#  8   Country        9994 non-null   object
#  9   City           9994 non-null   object
#  10  State          9994 non-null   object
#  11  Postal Code    9994 non-null   int64
#  12  Region         9994 non-null   object
#  13  Product ID     9994 non-null   object
#  14  Category       9994 non-null   object
#  15  Sub-Category   9994 non-null   object
#  16  Product Name   9994 non-null   object
# ...

# %% [markdown]
# ### Removing spaces in the columns

# %%
Super.columns =[column.replace(" ", "_")  for column in Super.columns]
Super.head()
# Out:
#    Row_ID        Order_ID  Order_Date   Ship_Date       Ship_Mode Customer_ID  \
# 0       1  CA-2016-152156   11/8/2016  11/11/2016    Second Class    CG-12520
# 1       2  CA-2016-152156   11/8/2016  11/11/2016    Second Class    CG-12520
# 2       3  CA-2016-138688   6/12/2016   6/16/2016    Second Class    DV-13045
# 3       4  US-2015-108966  10/11/2015  10/18/2015  Standard Class    SO-20335
# 4       5  US-2015-108966  10/11/2015  10/18/2015  Standard Class    SO-20335
#
#      Customer_Name    Segment        Country             City  ...  \
# 0      Claire Gute   Consumer  United States        Henderson  ...
# 1      Claire Gute   Consumer  United States        Henderson  ...
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  ...
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
#
#   Postal_Code  Region       Product_ID         Category Sub-Category  \
# ...

# %% [markdown]
# ### Converting the dates from object to data time format

# %%
Super['Order_Date']=pd.to_datetime(Super['Order_Date'])
Super['Ship_Date']=pd.to_datetime(Super['Ship_Date'])

# %%
Super.head()
# Out:
#    Row_ID        Order_ID Order_Date  Ship_Date       Ship_Mode Customer_ID  \
# 0       1  CA-2016-152156 2016-11-08 2016-11-11    Second Class    CG-12520
# 1       2  CA-2016-152156 2016-11-08 2016-11-11    Second Class    CG-12520
# 2       3  CA-2016-138688 2016-06-12 2016-06-16    Second Class    DV-13045
# 3       4  US-2015-108966 2015-10-11 2015-10-18  Standard Class    SO-20335
# 4       5  US-2015-108966 2015-10-11 2015-10-18  Standard Class    SO-20335
#
#      Customer_Name    Segment        Country             City  ...  \
# 0      Claire Gute   Consumer  United States        Henderson  ...
# 1      Claire Gute   Consumer  United States        Henderson  ...
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  ...
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
#
#   Postal_Code  Region       Product_ID         Category Sub-Category  \
# ...

# %%
Super.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Row_ID         9994 non-null   int64
#  1   Order_ID       9994 non-null   object
#  2   Order_Date     9994 non-null   datetime64[ns]
#  3   Ship_Date      9994 non-null   datetime64[ns]
#  4   Ship_Mode      9994 non-null   object
#  5   Customer_ID    9994 non-null   object
#  6   Customer_Name  9994 non-null   object
#  7   Segment        9994 non-null   object
#  8   Country        9994 non-null   object
#  9   City           9994 non-null   object
#  10  State          9994 non-null   object
#  11  Postal_Code    9994 non-null   int64
#  12  Region         9994 non-null   object
#  13  Product_ID     9994 non-null   object
#  14  Category       9994 non-null   object
#  15  Sub-Category   9994 non-null   object
#  16  Product_Name   9994 non-null   object
# ...

# %% [markdown]
# ### Adding columns Order_Year, Order_Month, Ship_Year, and Ship_Month

# %%
Super['Order_Year']=Super['Order_Date'].dt.year
Super['Order_Month']=Super['Order_Date'].dt.month
Super['Ship_Year']=Super['Ship_Date'].dt.year
Super['Ship_Month']=Super['Ship_Date'].dt.month

# %%
Super.head()
# Out:
#    Row_ID        Order_ID Order_Date  Ship_Date       Ship_Mode Customer_ID  \
# 0       1  CA-2016-152156 2016-11-08 2016-11-11    Second Class    CG-12520
# 1       2  CA-2016-152156 2016-11-08 2016-11-11    Second Class    CG-12520
# 2       3  CA-2016-138688 2016-06-12 2016-06-16    Second Class    DV-13045
# 3       4  US-2015-108966 2015-10-11 2015-10-18  Standard Class    SO-20335
# 4       5  US-2015-108966 2015-10-11 2015-10-18  Standard Class    SO-20335
#
#      Customer_Name    Segment        Country             City  ...  \
# 0      Claire Gute   Consumer  United States        Henderson  ...
# 1      Claire Gute   Consumer  United States        Henderson  ...
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  ...
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
#
#   Sub-Category                                       Product_Name     Sales  \
# ...

# %% [markdown]
# ### Using head, tail, sample, shape, info, and describe for a summary of the data set

# %%
Super.shape
# Out:
# (9994, 25)

# %%
Super.head()
# Out:
#    Row_ID        Order_ID Order_Date  Ship_Date       Ship_Mode Customer_ID  \
# 0       1  CA-2016-152156 2016-11-08 2016-11-11    Second Class    CG-12520
# 1       2  CA-2016-152156 2016-11-08 2016-11-11    Second Class    CG-12520
# 2       3  CA-2016-138688 2016-06-12 2016-06-16    Second Class    DV-13045
# 3       4  US-2015-108966 2015-10-11 2015-10-18  Standard Class    SO-20335
# 4       5  US-2015-108966 2015-10-11 2015-10-18  Standard Class    SO-20335
#
#      Customer_Name    Segment        Country             City  ...  \
# 0      Claire Gute   Consumer  United States        Henderson  ...
# 1      Claire Gute   Consumer  United States        Henderson  ...
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  ...
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
#
#   Sub-Category                                       Product_Name     Sales  \
# ...

# %%
Super.tail()
# Out:
#       Row_ID        Order_ID Order_Date  Ship_Date       Ship_Mode  \
# 9989    9990  CA-2014-110422 2014-01-21 2014-01-23    Second Class
# 9990    9991  CA-2017-121258 2017-02-26 2017-03-03  Standard Class
# 9991    9992  CA-2017-121258 2017-02-26 2017-03-03  Standard Class
# 9992    9993  CA-2017-121258 2017-02-26 2017-03-03  Standard Class
# 9993    9994  CA-2017-119914 2017-05-04 2017-05-09    Second Class
#
#      Customer_ID     Customer_Name   Segment        Country         City  ...  \
# 9989    TB-21400  Tom Boeckenhauer  Consumer  United States        Miami  ...
# 9990    DB-13060       Dave Brooks  Consumer  United States   Costa Mesa  ...
# 9991    DB-13060       Dave Brooks  Consumer  United States   Costa Mesa  ...
# 9992    DB-13060       Dave Brooks  Consumer  United States   Costa Mesa  ...
# 9993    CC-12220      Chris Cortes  Consumer  United States  Westminster  ...
#
#      Sub-Category                                       Product_Name    Sales  \
# ...

# %%
Super.sample(5)
# Out:
#       Row_ID        Order_ID Order_Date  Ship_Date       Ship_Mode  \
# 6931    6932  CA-2014-164182 2014-07-14 2014-07-18  Standard Class
# 987      988  CA-2015-146829 2015-03-10 2015-03-10        Same Day
# 79        80  CA-2016-127208 2016-06-12 2016-06-15     First Class
# 6298    6299  CA-2014-169852 2014-10-21 2014-10-26  Standard Class
# 2043    2044  US-2017-158946 2017-11-18 2017-11-23  Standard Class
#
#      Customer_ID       Customer_Name    Segment        Country          City  \
# 6931    ST-20530            Shui Tom   Consumer  United States  Philadelphia
# 987     TS-21340       Toby Swindell   Consumer  United States       Houston
# 79      SC-20770  Stewart Carmichael  Corporate  United States       Decatur
# 6298    SF-20965     Sylvia Foulston  Corporate  United States     San Diego
# 2043    JW-15220           Jane Waco  Corporate  United States      Lakewood
#
#       ... Sub-Category                                       Product_Name  \
# ...

# %%
Super.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 25 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Row_ID         9994 non-null   int64
#  1   Order_ID       9994 non-null   object
#  2   Order_Date     9994 non-null   datetime64[ns]
#  3   Ship_Date      9994 non-null   datetime64[ns]
#  4   Ship_Mode      9994 non-null   object
#  5   Customer_ID    9994 non-null   object
#  6   Customer_Name  9994 non-null   object
#  7   Segment        9994 non-null   object
#  8   Country        9994 non-null   object
#  9   City           9994 non-null   object
#  10  State          9994 non-null   object
#  11  Postal_Code    9994 non-null   int64
#  12  Region         9994 non-null   object
#  13  Product_ID     9994 non-null   object
#  14  Category       9994 non-null   object
#  15  Sub-Category   9994 non-null   object
#  16  Product_Name   9994 non-null   object
# ...

# %%
Super.isnull().sum() #no missing values in the data set
# Out:
# Row_ID           0
# Order_ID         0
# Order_Date       0
# Ship_Date        0
# Ship_Mode        0
# Customer_ID      0
# Customer_Name    0
# Segment          0
# Country          0
# City             0
# State            0
# Postal_Code      0
# Region           0
# Product_ID       0
# Category         0
# Sub-Category     0
# Product_Name     0
# Sales            0
# Quantity         0
# Discount         0
# Profit           0
# Order_Year       0
# Order_Month      0
# Ship_Year        0
# Ship_Month       0
# dtype: int64

# %%
Super.describe()
# Out:
#             Row_ID   Postal_Code         Sales     Quantity     Discount  \
# count  9994.000000   9994.000000   9994.000000  9994.000000  9994.000000
# mean   4997.500000  55190.379428    229.858001     3.789574     0.156203
# std    2885.163629  32063.693350    623.245101     2.225110     0.206452
# min       1.000000   1040.000000      0.444000     1.000000     0.000000
# 25%    2499.250000  23223.000000     17.280000     2.000000     0.000000
# 50%    4997.500000  56430.500000     54.490000     3.000000     0.200000
# 75%    7495.750000  90008.000000    209.940000     5.000000     0.200000
# max    9994.000000  99301.000000  22638.480000    14.000000     0.800000
#
#             Profit   Order_Year  Order_Month    Ship_Year   Ship_Month
# count  9994.000000  9994.000000  9994.000000  9994.000000  9994.000000
# mean     28.656896  2015.722233     7.809686  2015.737442     7.743146
# std     234.260108     1.123555     3.284654     1.126141     3.340476
# ...

# %% [markdown]
# ### Summery Statistics for Superstore Data

# %%
Super[['Sales', 'Quantity', 'Discount', 'Profit']].describe()
# Out:
#               Sales     Quantity     Discount       Profit
# count   9994.000000  9994.000000  9994.000000  9994.000000
# mean     229.858001     3.789574     0.156203    28.656896
# std      623.245101     2.225110     0.206452   234.260108
# min        0.444000     1.000000     0.000000 -6599.978000
# 25%       17.280000     2.000000     0.000000     1.728750
# 50%       54.490000     3.000000     0.200000     8.666500
# 75%      209.940000     5.000000     0.200000    29.364000
# max    22638.480000    14.000000     0.800000  8399.976000

# %%
Super.describe()
# Out:
#             Row_ID   Postal_Code         Sales     Quantity     Discount  \
# count  9994.000000   9994.000000   9994.000000  9994.000000  9994.000000
# mean   4997.500000  55190.379428    229.858001     3.789574     0.156203
# std    2885.163629  32063.693350    623.245101     2.225110     0.206452
# min       1.000000   1040.000000      0.444000     1.000000     0.000000
# 25%    2499.250000  23223.000000     17.280000     2.000000     0.000000
# 50%    4997.500000  56430.500000     54.490000     3.000000     0.200000
# 75%    7495.750000  90008.000000    209.940000     5.000000     0.200000
# max    9994.000000  99301.000000  22638.480000    14.000000     0.800000
#
#             Profit   Order_Year  Order_Month    Ship_Year   Ship_Month
# count  9994.000000  9994.000000  9994.000000  9994.000000  9994.000000
# mean     28.656896  2015.722233     7.809686  2015.737442     7.743146
# std     234.260108     1.123555     3.284654     1.126141     3.340476
# ...

# %% [markdown]
# ## Visuallization

# %%
Super.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 25 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Row_ID         9994 non-null   int64
#  1   Order_ID       9994 non-null   object
#  2   Order_Date     9994 non-null   datetime64[ns]
#  3   Ship_Date      9994 non-null   datetime64[ns]
#  4   Ship_Mode      9994 non-null   object
#  5   Customer_ID    9994 non-null   object
#  6   Customer_Name  9994 non-null   object
#  7   Segment        9994 non-null   object
#  8   Country        9994 non-null   object
#  9   City           9994 non-null   object
#  10  State          9994 non-null   object
#  11  Postal_Code    9994 non-null   int64
#  12  Region         9994 non-null   object
#  13  Product_ID     9994 non-null   object
#  14  Category       9994 non-null   object
#  15  Sub-Category   9994 non-null   object
#  16  Product_Name   9994 non-null   object
# ...

# %% [markdown]
# ### Sales Plots

# %%
#Sales distibution
plt.figure(figsize=(10,8))

#mean and median
mean=Super['Sales'].mean()
median=Super['Sales'].median()

sns.histplot(x='Sales', 
            data=Super)

plt.axvline(mean, color='yellow')
plt.axvline(median, color='white')

plt.show()

# %%
plt.figure(figsize=(20,16))
sns.boxplot(x=Super['Sales'])

plt.show()

# %%
#line plot of sales over the years
sy=sns.lineplot(x='Order_Year',
                y='Sales', 
                data=Super)
plt.xlabel('Year')
plt.ylabel('Sales')
plt.title('Sales from 2014-2017')
plt.show()

# %%
sns.set(rc={'figure.figsize':(10,8)})
bar_plot=sns.barplot(x='Order_Year',
                    y='Sales', 
                    data=Super,
                    ci=False,
                    hue='State'
                    )
plt.xlabel('Year')
plt.ylabel('Sales')
plt.title('Sales by State (2014-2017)')
plt.legend(bbox_to_anchor=(1.02, 1.5), loc='upper left')

plt.show()

# %% [markdown]
# ### Profit Plots

# %%
#Profit distibution
plt.figure(figsize=(8,6))

#mean and median
mean=Super['Profit'].mean()
median=Super['Profit'].median()

sns.histplot(x='Profit', 
            data=Super)

plt.axvline(mean, color='yellow')
plt.axvline(median, color='white')

plt.show()

# %%
plt.figure(figsize=(20,16))
sns.boxplot(x=Super['Profit'])

plt.show()

# %%
#profit over the year
py=sns.lineplot(x='Order_Year',
                y='Profit', 
                data=Super)
plt.xlabel('Year')
plt.ylabel('Profit')
plt.title('Profits from 2014-2017')
plt.show()

# %%
plt.figure(figsize=(14,12))
bar_plot=sns.barplot(x='Order_Year',
                    y='Profit', 
                    data=Super,
                    ci=False,
                    hue='State'
                    )
plt.xlabel('Year')
plt.ylabel('Profit')
plt.title('Profit by State (2014-2017)')
plt.legend(bbox_to_anchor=(1.02, 1.02), loc='upper left')

plt.show()

# %% [markdown]
# ### Discount plots

# %%
sns.set(rc={'figure.figsize':(6,4)})
sns.histplot(x='Discount', 
            data=Super)
# Out:
# <AxesSubplot:xlabel='Discount', ylabel='Count'>

# %%
plt.figure(figsize=(16,12))
sns.boxplot(x=Super['Discount'])

plt.show()

# %%
sns.barplot(x='Order_Month',
           y='Discount',
           data=Super)
plt.xlabel('Month')
plt.ylabel('Discount (%)')

plt.show()

# %%
sns.barplot(x='Order_Year',
           y='Discount',
           data=Super)
plt.xlabel('Year')
plt.ylabel('Discount (%)')

plt.show()

# %% [markdown]
# ### Quantity of Orders

# %%
sns.set(rc={'figure.figsize':(6,4)})
sns.histplot(x='Quantity', 
            data=Super)
plt.xlabel('Quantity of Items Ordered per Order')

plt.show()

# %%
plt.figure(figsize=(20,20))
sns.barplot(x="Quantity", 
            y="State", 
            data=Super, 
            ci=False, 
            orient='h'
           )
plt.xlabel("Number of Items in Order")

plt.show()

# %% [markdown]
# ### Customers

# %%
plt.figure(figsize=(20,60))
sns.histplot(x='Customer_Name',
            data=Super,
           )
plt.title("Amount of Order per Customer")

plt.show()

# %%
sns.lineplot(x='Quantity', 
            y='State',
            data=Super)
#The amount of items in an order from each state
# Out:
# <AxesSubplot:xlabel='Quantity', ylabel='State'>

# %% [markdown]
# ### Scatter plot comparisons

# %%
plt.scatter(Super['Sales'],Super['Quantity'])
plt.xlabel('Sales ($)')
plt.ylabel('Quantity of Item per Order')
plt.title('Sales vs Quantity')

plt.show()

# %%
plt.scatter(Super['Profit'],Super['Quantity'])
plt.xlabel('Profit ($)')
plt.ylabel('Quantity of Item per Order')
plt.title('Profit vs Quantity')

plt.show()

# %%
plt.scatter(Super['Discount'],Super['Quantity'])
plt.xlabel('Discount (%)')
plt.ylabel('Quantity of Item per Order')
plt.title('Discount vs Quantity')

plt.show()

# %%
Super.columns
# Out:
# Index(['Row_ID', 'Order_ID', 'Order_Date', 'Ship_Date', 'Ship_Mode',
#        'Customer_ID', 'Customer_Name', 'Segment', 'Country', 'City', 'State',
#        'Postal_Code', 'Region', 'Product_ID', 'Category', 'Sub-Category',
#        'Product_Name', 'Sales', 'Quantity', 'Discount', 'Profit', 'Order_Year',
#        'Order_Month', 'Ship_Year', 'Ship_Month'],
#       dtype='object')
